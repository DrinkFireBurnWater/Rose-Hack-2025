# %%
#IMPORTS
import json

# %%
with open('newsdata.json') as json_file:
    newsdata = json.load(json_file)
newsdata = dict(newsdata)
newsdata = newsdata["data"]
# Out:
# [{'author': 'David Zucchino and Zia ur-Rehman', 'title': 'They Were Waiting for Flights. Then Trump Closed a Door for Afghan Allies.', 'description': 'An executive order has halted refugee flights for Afghans who supported the American mission in Afghanistan and had been approved to resettle in the U.S.', 'url': 'https://www.nytimes.com/2025/01/25/world/asia/trump-executive-order-immigration-afghanistan.html', 'source': 'nytimes', 'image': 'https://static01.nyt.com/images/2025/01/24/multimedia/24afghan-refugees-1-hbmp/24afghan-refugees-1-hbmp-mediumSquareAt3X.jpg', 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-01-25T22:48:24+00:00'}, {'author': None, 'title': 'Riley Gaines tears into WNBA star who gave Caitlin Clark black eye for wearing anti-Trump shirt', 'description': 'Podcast host Riley Gaines jumped in on the backlash against WNBA player DiJonai Carrington after Carrington wore an anti-Trump shirt Friday.', 'url': 'https://www.foxnews.com/sports/riley-gaines-tears-wnba-star-who-gave-caitlin-clark-black-eye-wearing-anti-trump-shirt', 'source': 'FOX News - Most Popular', 'image': 'https://a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2025/01/931/523/gaines-clark.jpg?ve=1&tl=1', 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-01-25T22:45:30+00:00'}, {'author': None, 'title': 'Match of the Day', 'description': 'Highlights from another exciting day of action in the Premier League.', 'url': 'https://www.bbc.co.uk/iplayer/live/bbcone', 'source': 'BBC', 'image': 'https://ichef.bbci.co.uk/images/ic/240x135/p0klj68w.jpg', 'category': 'general', 'language': 'en', 'country': 'gb', 'published_at': '2025-01-25T22:40:13+00:00'}, {'author': None, 'title': 'Una corte de Pakistán condena a cuatro personas a muerte por blasfemia', 'description': 'MULTAN, Pakistán (AP) — Un tribunal de Pakistán condenó el sábado a cuatro personas a la pena capital por blasfemia luego de la presunta publicación de material sacrílego en redes sociales sobre figuras religiosas islámicas y el Corán.', 'url': 'https://www.latimes.com/espanol/internacional/articulo/2025-01-25/una-corte-de-pakistan-condena-a-cuatro-personas-a-muerte-por-blasfemia', 'source': 'latimes', 'image': None, 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-01-25T22:35:35+00:00'}, {'author': 'Patrick Kingsley, Aaron Boxerman, Adam Rasgon and Thomas Fuller', 'title': 'As Hamas Releases More Israeli Hostages, It Puts on a Show of Force', 'description': 'The handover of four female Israeli soldiers by Hamas on Saturday came as Israel released 200 prisoners. But a dispute arose over the hostage release timetable.', 'url': 'https://www.nytimes.com/2025/01/25/world/middleeast/israel-gaza-hostage-prisoner-swap.html', 'source': 'The New York Times', 'image': 'https://static01.nyt.com/images/2025/01/25/multimedia/25mideast-ledeall-01-mhtg/25mideast-ledeall-01-mhtg-mediumSquareAt3X.jpg', 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-01-25T22:07:31+00:00'}, {'author': None, 'title': 'The CIA believes COVID likely originated from a lab but has low confidence in its own finding', 'description': "The CIA believes the COVID-19 virus likely originated from a laboratory — but acknowledges the spy agency has 'low confidence' in its own conclusion.", 'url': 'https://www.latimes.com/world-nation/story/2025-01-25/the-cia-believes-covid-likely-originated-from-a-lab-but-has-low-confidence-in-its-own-finding', 'source': 'latimes', 'image': None, 'category': 'general', 'language': 'en', 'country': 'us', 'published_at': '2025-01-25T22:00:25+00:00'}, {'author': None, 'title': 'Israel y Hamás preparan nuevo intercambio de rehenes y prisioneros', 'description': 'Israel y Hamás tienen programado un intercambio de rehenes y prisioneros el sábado, el segundo desde que comenzó el alto el fuego en la Franja de Gaza el fin de semana pasado y otra prueba para el acuerdo.', 'url':  ...
# <class 'list'>

# %%
data = []
copycolumns = ['title', 'source', 'description']
for article in newsdata:
    filterarticle = {key: article[key] for key in copycolumns}
    filterarticle['source'] = filterarticle['source'].split(" ")[0]
    data.append(filterarticle)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def sentiment_scores(sentence):

    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()

    # polarity_scores method of SentimentIntensityAnalyzer object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)

    # Decide sentiment as positive, negative, or neutral

    return sentiment_dict['compound']

# %%
for article in data:
    score1 = sentiment_scores(article['title'])
    score2 = sentiment_scores(article['description'])
    score = (score1+score2)/2
    article['score'] = score

# %%
for article in data:
    print(article['title'])
    print(article['score'])
# Out:
# They Were Waiting for Flights. Then Trump Closed a Door for Afghan Allies.
# 0.31245
# Riley Gaines tears into WNBA star who gave Caitlin Clark black eye for wearing anti-Trump shirt
# -0.11315
# Match of the Day
# 0.24695
# Una corte de Pakistán condena a cuatro personas a muerte por blasfemia
# 0.0
# As Hamas Releases More Israeli Hostages, It Puts on a Show of Force
# -0.3454
# The CIA believes COVID likely originated from a lab but has low confidence in its own finding
# 0.4215
# Israel y Hamás preparan nuevo intercambio de rehenes y prisioneros
# 0.0
# Hegseth’s Views May Clash With Reality at Defense Department
# 0.128
# A Nuggets fan was hired by Nike to paint a Kobe Bryant mural in Venice Beach. 'It was an honor'
# 0.33525
# Trump declara una emergencia fronteriza en un periodo de calma tras años de gran agitación
# 0.0
# Estas fueron las 10 canciones más populares de la semana
# -0.27115
# Ex-probation officer arrested on suspicion of sexual contact with juvenile inmate
# -0.8013
# Bangkok tackles smog with week-long free public transport
# 0.3919
# U.S. Halt to Foreign Aid Does Not Apply to Arms to Israel and Egypt
# 0.07655
# WH Smith in talks to sell high street stores
# 0.24385
# Auschwitz 80 years since liberation: Ryszard Horowitz's story of survival and making the American Dream
# 0.3544
# As L.A. Welcomes Rain Amid Fires, It Tries to Reduce Risk of Mudslides
# -0.19074999999999998
# New recovery center to open in Altadena to aid Eaton fire victims
# -0.70175
# Four Israeli hostages released by Hamas in carefully-staged handover
# -0.2553
# Europe posts record year for clean energy use as Trump pushes U.S. toward fossil fuels
# 0.29295
# England slide to defeat by India in second T20
# -0.65535
# Israel and Hamas Dispute Over Hostage Leaves Displaced Palestinians Waiting
# -0.21384999999999998
# Senate confirms Kristi Noem as Trump's Homeland Security secretary
# 0.34
# Carlos Morales Jr. busca el camino a Los Ángeles 2028 bajo las enseñanzas de su padre
# 0.0
# Latinx Files: The battle over immigration ramps up
# -0.1909
# Sabalenka lanza su raqueta tras perder ante Madison Keys la final del Abierto de Australia
# 0.0
# Madison Keys atribuye su mejora a la terapia su ayuda dentro y fuera de la cancha
# 0.05135
# Growth at all costs? Why Reeves is in a sudden rush on the economy
# 0.1909
# Con doblete de Retegui, Atalanta revive esperanzas en la Serie A con victoria ante Como
# 0.17
# 200 Palestinian prisoners released to jubilant scenes in West Bank
# -0.16635000000000003
# C.I.A. Now Favors Lab Leak Theory to Explain Covid’s Origins
# -0.05135
# Boy, 14, charged with murder of Leo Ross, 12
# -0.8134
# David Lammy 'horrified' after meeting Sudan war victims face-to-face
# -0.34815
# Pete Hegseth Confirmed as Defense Secretary as Vance Breaks Tie Vote
# -0.08399999999999999
# Husband of wife found dead detained in Thailand
# -0.3953
# L.A. County officials need federal aid. How long can they play nice with Trump?
# 0.7566999999999999
# Trump went full despot on Day 1, pardoning Jan. 6 rioters
# 0.18805
# AI Can Work for Us
# 0.0
# What you should learn from these 4 major challenges Trump overcame to win back the White House
# 0.6887000000000001
# Thomas Gaither, Who Chose Jail After Civil Rights Sit-ins, Dies at 86
# -0.4111
# Hamas frees 4 female Israeli soldiers as part of the Gaza cease-fire in exchange for 200 prisoners
# -0.1366
# Bird flu prevention zone imposed in England
# -0.4111
# Why Trump's holding weekend rally in Las Vegas less than a week into new admin
# 0.0258
# ‘We were 100% alone’: Fire alerts came too late for some Altadena residents
# -0.34
# Underdog Keys beats Sabalenka to win Australian Open
# 0.7505999999999999
# America's energy crisis is hiding in plain sight and it's worse than you know
# -0.29055
# Floods, landslides are a risk as fire-scarred Los Angeles girds for rain
# -0.0116
# Fox News AI Newsletter: Musk vs. Altman
# 0.2202
# 'Harpoon Hunters' star compares waiting for tuna to a 'sniper waiting to take a shot'
# 0.1806
# Hamas Choreographs a Show of Force as It Hands Over the Hostages
# -0.0258
# Three teenagers die after car hits tree
# -0.624
# England bowled out for 90 as Australia close on clean sweep
# 0.6122
# 'What a catch!' Voll's spectacular effort removes Ecclestone
# 0.0
# June 1, 2024 - Israel-Gaza news
# -0.4221
# Superb Keys stuns Sabalenka to win first Grand Slam title
# 0.84985
# L.A. fires upend fragile child-care industry, sending providers, families scrambling
# 0.24695
# UC, a top recipient of federal research funding, is concerned about Trump pause on grant reviews
# 0.5106
# The start of the Palisades and Eaton fires: 24 hours that changed Los Angeles
# 0.0
# As Eaton fire advanced, here's how employees rescued 45 elderly and disabled patients
# 0.38075000000000003
# Community groups set up strike teams to respond to Trump's mass deportation plans
# -0.064
# In a Long Beach parking lot, charros put on 'El Show de los Caballos'
# 0.0
# Altadena residents feel forgotten as Trump tours Pacific Palisades fire devastation
# -0.528
# Quebec’s Ban on Religious Symbols Will Be Tested at the Supreme Court
# -0.2553
# Storm Éowyn clean-up operation gets under way
# -0.2997
# Clean-up of 'significant' storm damage begins
# -0.17
# Israel Welcomes the Return of the Women Who Warned of a Raid From Gaza
# -0.385
# June 8, 2024 - Israel-Gaza news
# -0.3753
# How Trump Shifted Policy in Week 1, on Immigration, DEI and More
# -0.148
# Trump’s Crypto Venture Divides the Industry He Aims to Support
# 0.12439999999999998
# His Opponents Sidelined, Lukashenko Is Set for a 7th Term in Belarus
# 0.425
# Gunfire and Bandits Make School an Impossible Dream for Haitian Children
# -0.16375
# Inside the $32 Billion Industry Transforming Marijuana
# 0.1591
# Here’s What We Know About the 4 Released Hostages
# -0.3753
# Man who died after tree fell on car in Donegal named
# -0.2787
# Hamas Hostages Are Released to Israeli Forces
# -0.2553
# Hamas releases 4 female hostages as part of Israel ceasefire deal
# -0.3454
# Glencorse Massacre: 'I discovered the bodies of three murdered soldiers'
# -0.25329999999999997
# Hombre admite ser autor de ojos saltones en arte público de Oregon
# -0.148
# ¿Qué opinan los estadounidenses sobre los planes de Trump y Musk para el gobierno federal?
# -0.148
# Trump hereda una economía sólida, será difícil que bajen las tasas o la inflación
# 0.0
# Por fin llega la lluvia al sur de California: lo que necesitas saber
# 0.0
# Cat stuck up 33ft tree for three days rescued
# -0.06885000000000001
# 189,000 without power after Storm Éowyn batters NI
# 0.0
# Camping with the far-right: What I learned from a year inside Patriotic Alternative
# 0.0
# Aday Mara doesn't miss in crunch time as resurgent UCLA defeats Washington
# 0.09305
# Poca taquilla en México para 'Emilia Pérez', que es considerada 'un retrato superfluo de sus problemas'
# 0.0
# Trump Fires 17 Inspectors General in Late-Night Purge
# 0.26335
# Job cut fears and PM 'rejects whole-life term reform'
# -0.68415
# Paul McCartney: Don't let AI rip off artists
# 0.0
# Myanmar Rebels Are Opening Colleges
# -0.40085000000000004
# Argentina golea 6-0 a Brasil y Ecuador supera Bolivia al abrirse el Grupo B del Sudamericano Sub20
# 0.0
# U.S. Military Planes Carrying Migrants Land in Guatemala
# 0.064
# Hegseth Is Second Cabinet Secretary to Need Tiebreaker Vote, After DeVos
# 0.23005
# Hegseth confirmed as Trump's Defense secretary, as Vance casts tiebreaking vote
# 0.128
# Trump ordena publicar archivos sobre los asesinatos de los hermanos Kennedy y Luther King Jr
# 0.0
# In Visit to Pacific Palisades, Trump Praises Firefighters and Blames Democratic Officials
# -0.35
# Idaho Lawmakers Want Supreme Court to Overturn Same-Sex Marriage Decision
# 0.4247
# Last 4 Monkeys That Escaped in South Carolina Are Captured
# 0.0
# Almost everything Trump did in his whirlwind first week
# 0.1806
# Immigration Arrests Prompt Fear That Mass Deportations Loom
# -0.68825

# %%
totals = dict()

for article in data:
    score1 = sentiment_scores(article['title'])
    score2 = sentiment_scores(article['description'])
    score = (score1+score2)/2
    article['score'] = score

for article in data:
    if article['source'] not in totals:
        totals[article['source']] = [0,0]
    #print(article['score'])
    totals[article['source']][0] += article['score']
    #print(totals[article['source']])
    totals[article['source']][1] += 1

#print(totals)

for news in totals:
    totals[news][0] = totals[news][0]/totals[news][1]

print(totals)
# Out:
# {'nytimes': [-0.86065, 5], 'FOX': [0.7206000000000004, 8], 'BBC': [-1.9568000000000003, 26], 'latimes': [0.57385, 36], 'The': [-1.27575, 23], 'CNN': [-0.7974, 2]}
# {'nytimes': [-0.17213, 5], 'FOX': [0.09007500000000004, 8], 'BBC': [-0.07526153846153848, 26], 'latimes': [0.015940277777777775, 36], 'The': [-0.05546739130434782, 23], 'CNN': [-0.3987, 2]}
